# %% [markdown]
# ![image.png](attachment:image.png)

# %%
doorclose=True
doorlock=True
def unlockdoor():
    doorclose=True
def advance():
    print("door open")
opendoor=True
if doorclose==True:
    if doorlock==True:
        unlockdoor()
    opendoor=True
    advance()
else:
    advance()
# Out:
# door open

# %%
print(help(all))
# Out:
# Help on built-in function all in module builtins:
#
# all(iterable, /)
#     Return True if bool(x) is True for all values x in the iterable.
#
#     If the iterable is empty, return True.
#
# None

# %%
return True if bool(x) is True for all values x in the iterable.

if the iterable is empty, return True.
# Out:
#   Cell In[6], line 1
#     return True if bool(x) is True for all values x in the iterable.
#            ^
# SyntaxError: expected 'else' after 'if' expression

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = [True , False, True, True]

# %%
all(x) #lie and operator
# Out:
# False

# %%
any(x) # ,like or operator
# Out:
# True

# %%
chr(14)

# %%
x=divmod()
# Out:
# (3, 1)

# %%
hash(print)
# Out:
# 8764747099664

# %%
isinstance([1,2], list)
# Out:
# True

# %%
#x = [1,2,3]
x = (1,2,3)

# change the last value
if isinstance(x,tuple):
    x = list(x)
    x[-1] = "ahhahahahah"
    x = tuple(x)
else:
    x[-1] = "ahhahahahah"


print(x)
# Out:
# (1, 2, 'ahhahahahah')

# %%
import librarieseasily
