# %% [markdown]
# Objects are actually data types, or data sequence or mapping objects

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# reserved words
yield
assert
global

# %%
False as continue else from in not return yield
None assert def except global is or try
True break del finally if lambda pass while
and class elif for import nonlocal raise with

# %%
"apple" == "Apple"
# Out:
# False

# %%
apple = 8
Apple = 7
@pple

# %%
# assignment statement
a=8

# %%
a=98.6

# %%
b=a

# %%
print(id(a))
print(id(b))
# Out:
# 140694817487984
# 140694817487984

# %% [markdown]
# <h1> mutable </h1>

# %%
list
dict
set
bytearray
deque
# User-defined Classes (if designed to be mutable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/andymiaogu/Desktop/Andy's coding/Data structure and Algorithms by M T Goodrich/Ch 1 Python Primer/topic 1 Objects in python.ipynb Cell 12 line 5
#       <a href='vscode-notebook-cell:/Users/andymiaogu/Desktop/Andy%27s%20coding/Data%20structure%20and%20Algorithms%20by%20M%20T%20Goodrich/Ch%201%20Python%20Primer/topic%201%20Objects%20in%20python.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> set
#       <a href='vscode-notebook-cell:/Users/andymiaogu/Desktop/Andy%27s%20coding/Data%20structure%20and%20Algorithms%20by%20M%20T%20Goodrich/Ch%201%20Python%20Primer/topic%201%20Objects%20in%20python.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> bytearray
# ...

# %% [markdown]
# # immutable

# %%
tuple
str
int
float
bool
frozenset
bytes
complex
frozenset
namedtuple (from the collections module)
enum (from the enum module)
# Out:
#   Cell In[19], line 10
#     namedtuple (from the collections module)
#                 ^
# SyntaxError: invalid syntax
