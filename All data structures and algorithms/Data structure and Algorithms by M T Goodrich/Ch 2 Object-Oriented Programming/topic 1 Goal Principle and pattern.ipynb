# %% [markdown]
# ##### Object-Oriented Design Goals
# ![image.png](attachment:image.png)

# %%
def add (x,y):
    # robust 
    x=float(x)
    y=float(y)
    return x+y

# %%
add(8,'4')
# Out:
# 12.0
