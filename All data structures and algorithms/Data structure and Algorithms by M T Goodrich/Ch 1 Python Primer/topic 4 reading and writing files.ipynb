# %%
reply = input("please write the value of x and y?")
print(reply)
reply=reply.split(", ")
x = reply[0]
y = reply[1]
print(f"x = {x}, and y = {y}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/andymiaogu/Desktop/Andy's coding/Data structure and Algorithms by M T Goodrich/Ch 1 Python Primer/topic 4 reading and writing files.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:/Users/andymiaogu/Desktop/Andy%27s%20coding/Data%20structure%20and%20Algorithms%20by%20M%20T%20Goodrich/Ch%201%20Python%20Primer/topic%204%20reading%20and%20writing%20files.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> reply=reply.split(", ")
#       <a href='vscode-notebook-cell:/Users/andymiaogu/Desktop/Andy%27s%20coding/Data%20structure%20and%20Algorithms%20by%20M%20T%20Goodrich/Ch%201%20Python%20Primer/topic%204%20reading%20and%20writing%20files.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> x = reply[0]
# ...

# %%
age=1
maxheartrate=206.9-(0.67*age)
maxheartrate*0.65
# Out:
# 134.04950000000002

# %% [markdown]
# ![image.jpeg](attachment:image.png)

# %% [markdown]
# # Genre
